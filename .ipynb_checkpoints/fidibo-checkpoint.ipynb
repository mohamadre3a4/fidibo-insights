# %% [markdown]
# # Fidibo insights

# %% [markdown]
# ### calculate diffrence in book price

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('fidibo_books.csv')
data['price_diff'] = data['paper_price'] - data['price']
data=data.replace('NaN',np.nan)
data.head()
# Out:
#                    title  price  paper_price           isbn  rating   page  \
# 0   انسان در جستجوی معنی   8000      15000.0  9789646104266    4.38  255.0
# 1        مردی به نام اوه   8500      24500.0  9786007141779    4.34  392.0
# 2    درنگ نکن انجامش بده  12000      20000.0  9786005253139    4.15   97.0
# 3  سیزده دلیل برای اینکه   5900          NaN            NaN    3.74  300.0
# 4       تاریخ ایران مدرن  15000      25000.0  9789641851264    4.64  352.0
#
#        publisher  price_diff
# 0  انتشارات درسا      7000.0
# 1        نشر نون     16000.0
# 2  انتشارات سیته      8000.0
# 3       ناشرمولف         NaN
# 4         نشر نی     10000.0

# %% [markdown]
# ### histogram plots for columns

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.subplot(2, 2, 1)
plt.hist(data['price'], 50, facecolor='g')
plt.title('Histogram of price')
plt.subplot(2, 2, 2)
plt.hist(data['paper_price'], 50, facecolor='b')
plt.title('Histogram of paper_price')
plt.subplot(2, 2, 3)
plt.hist(data['rating'], 50, facecolor='y')
plt.title('Histogram of rating')
plt.subplot(2, 2, 4)
plt.hist(data['price_diff'], 50, facecolor='r')
plt.title('Histogram of price_diff')
plt.tight_layout()
plt.savefig('hists.png')
plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# apparently all data columns have some points out of range but are not an outlier.
# but a rating histogram point is too high so we need to investigate this plot more:

# %%
plt.hist(data['rating'], 100, facecolor='y')
plt.savefig('rating_hist.png')
plt.show()

# %%
rating = data[data['rating'] == 5]
rating.head()
# Out:
#                          title  price  paper_price           isbn  rating  \
# 67                    چای نعنا  15000      25000.0  ۹۷۸۶۰۰۸۴۸۲۰۷۹     5.0
# 70   هری‌پاتر و زندانی آزکابان  25000      31000.0  9789645757012     5.0
# 365               ماتریکس الهی  12500      25000.0  9786006721309     5.0
# 372               آن‌سوی اتهام  15000          NaN     9643126226     5.0
# 388                 طریق شاهان  15000      35000.0  9786006225845     5.0
#
#       page                publisher  price_diff
# 67   168.0                 نشر مثلث     10000.0
# 70   496.0  انتشارات کتابسرای تندیس      6000.0
# 365  264.0                 نشر نامک     12500.0
# 372  288.0                   نشر نی         NaN
# 388  632.0                   آذرباد     20000.0

# %% [markdown]
# so about 700 data rows are 5, it might be because fidibo ratings has a default value of 5
# but after checking these rows they are fine and it's not default value.

# %% [markdown]
# ### finding relationship between columns

# %%
sns.lmplot(x="price", y="rating", data=data)
plt.show()
sns.lmplot(x="rating", y="price_diff", data=data)
plt.show()

# %% [markdown]
# no pattern in these two plot... next we should check its columns correlation
# ### columns correlation

# %%
data.corr()
# Out:
#                                                   title  price  paper_price  \
# 0                                  انسان در جستجوی معنی   8000      15000.0
# 1                                       مردی به نام اوه   8500      24500.0
# 2                                   درنگ نکن انجامش بده  12000      20000.0
# 3                                 سیزده دلیل برای اینکه   5900          NaN
# 4                                      تاریخ ایران مدرن  15000      25000.0
# 5                                        هنر شناخت مردم  11200      28000.0
# 6                     قدرت فکر یا نیروی ذهن نیمه‌هوشیار   9000      18000.0
# 7                                                سینوهه  25000      50000.0
# 8                                              جهانی نو  13750      25000.0
# 9                                      تربیت بدون فریاد  10800      18000.0
# 10                                    برادران کارامازوف  18750      37500.0
# 11                                             بی تابوت   9900          NaN
# 12                                               محاکمه  10800      18000.0
# 13                                          غرور و تعصب  11000          NaN
# 14                               کلید کاربردی قانون جذب   9000      18000.0
# 15                                  احتمالاً گم شده‌ام‌   8400      14000.0
# 16                                 دموکراسی یا دموقراضه   5890       9000.0
# 17                  چرا با آدم‌ اشتباهی ازدواج می‌کنید؟   4900          NaN
# 18                                            جنگ و صلح  23000      50000.0
# 19                                           مارک و پلو  15000      22000.0
# 20                                           آوای فاخته  30000      50000.0
# 21                                هری پاتر و محفل ققنوس  15000      30000.0
# 22                                                کلیدر  12500          NaN
# 23                                                  راز  11500      23000.0
# 24                                           مدیریت خود  11000      28000.0
# 25                                                 قدیس  24200      35000.0
# 26                                      موش‌ها و آدم‌ها   6500      13000.0
# 27                                      تمرین نیروی حال   7500      12500.0
# 28                      خلاصه ۵۰  برتر در زمینه خودیاری   7500          NaN
# 29                                          مادام بواری   8000      16500.0
# ...                                                 ...    ...          ...
# 3748                        معماهای  هوش ۹  – تجسم ذهنی   2000          NaN
# 3749                     معماهای  هوش ۱۲  – هوش فضایی ۲   2000          NaN
# 3750                                    در آغوش نور - ۲  15000      26000.0
# 3751                     معماهای  هوش ۱۱  – هوش فضایی ۱   2000          NaN
# 3752                                هوش، دقت و توجه - ۱   2000       8000.0
# 3753                                هوش، دقت و توجه - ۲   2000       8000.0
# 3754                 معماهای  هوش ۸  – کشف روابط ساده ۳   2000          NaN
# 3755                                هوش، دقت و توجه - ۵   2000       8000.0
# 3756                    هوش آزمایی کودکان ۱  – سطح ساده   2000       9000.0
# 3757                                کسی صدا می‌زند لیلی   4500          NaN
# 3758                               مگره و يكصد چوبه دار   2400       6000.0
# 3759                               روانشناسی خود‌انگاره   1900          NaN
# 3760                                  شاه، بی‌بی، سرباز  15000          NaN
# 3761                                               نبرد  20000      43000.0
# 3762              ده داستان کوتاه از نویسندگان بزرگ روس  12500      25000.0
# 3763                           هالیوود چگونه کار می‌کند   8500          NaN
# 3764                                فکر کن، پیدا کن - ۲   2000      10000.0
# 3765                                        خشم فرشتگان   3000       6000.0
# 3766                                فکر کن، پیدا کن - ۵   2000      10000.0
# 3767                        بازی‌های ساده با کودکان - ۲   2000      10000.0
# 3768                                فکر کن، پیدا کن - ۳   2000      10000.0
# 3769                        بازی‌های ساده با کودکان - ۳   2000      10000.0
# 3770                        بازی‌های ساده با کودکان - ۴   2000      10000.0
# 3771                              ادیان ابتدایی و خاموش   8000      14000.0
# 3772  هوش و مهارت‌های کودکان – ادراک دیداری و کشف رو...   2000          NaN
# 3773     درک تفاوت وشباهت‌ها - هوش و مهارت‌های کودکان ۳   2000          NaN
# 3774                        بازی‌های ساده با کودکان - ۵   2000      10000.0
# 3775                               تاریخ و عملکرد مافیا   5000          NaN
# 3776                                فکر کن، پیدا کن - ۱   2000      10000.0
# 3777  ادراک شنیداری و درک مطلب – هوش و مهارت‌های کود...   2000      11000.0
#
#                isbn  rating   page                         publisher  \
# 0     9789646104266    4.38  255.0                     انتشارات درسا
# 1     9786007141779    4.34  392.0                           نشر نون
# 2     9786005253139    4.15   97.0                     انتشارات سیته
# 3               NaN    3.74  300.0                          ناشرمولف
# 4     9789641851264    4.64  352.0                            نشر نی
# 5     9789643635572    4.25  304.0                              هرمس
# 6     9789646617940    3.64  296.0                  نشر معیار اندیشه
# 7      978964111902    4.75  336.0                 انتشارات اردیبهشت
# 8     9789647974837    4.30  288.0                       کلک آزادگان
# 9     9879642785278    4.92  215.0                   انتشارات صابرین
# 10       9646205070    4.39  512.0                    انتشارات ناهید
# 11    9786005639933    4.73  208.0              گروه انتشاراتی ققنوس
# 12    9789649971544    4.00  271.0                          نشر ماهی
# 13    9789643696962    4.00  569.0                           نشر افق
# 14    9789648759426    4.30  163.0                     انتشارات درسا
# 15    9789643625429    4.05  143.0                          نشر چشمه
# 16    9789643374877    4.43  192.0              انتشارات کتاب نیستان
# 17              NaN    3.67    0.0                          ناشرمولف
# 18    9789644480270    3.40  707.0                        نشر نیلوفر
# 19    9789648496673    4.69  186.0                          نشر مثلث
# 20    9786001821196    3.63  656.0           انتشارات کتابسرای تندیس
# 21       9645757738    4.65  408.0           انتشارات کتابسرای تندیس
# 22    9789648637649    4.83  690.0              انتشارات فرهنگ معاصر
# 23    9786005138528    4.02  215.0                    انتشارات لیوسا
# 24    9786008237044    3.87  240.0                   انتشارات آموخته
# 25    9789643376772    4.00  298.0              انتشارات کتاب نیستان
# 26    9786007987018    3.82  160.0                     انتشارات مجید
# 27    9789649306339    4.67  111.0                       کلک آزادگان
# 28    9786005248135    4.44  383.0                             راشین
# 29    9789640016985    4.00  392.0                 انتشارات امیرکبیر
# ...             ...     ...    ...                               ...
# 3748  ۹۷۸۶۲۲۶۰۹۱۱۲۱     NaN   42.0                       کتاب کودکان
# 3749  ۹۷۸۶۲۲۶۰۹۱۱۵۲     NaN   42.0                       کتاب کودکان
# 3750     9646581757    3.56  348.0                           نشر تیر
# 3751  ۹۷۸۶۲۲۶۰۹۱۱۴۵     NaN   42.0                       کتاب کودکان
# 3752  9786226091190     NaN   27.0                       کتاب کودکان
# 3753  9786226091190     NaN   27.0                       کتاب کودکان
# 3754  ۹۷۸۶۲۲۶۰۹۱۱۱۴     NaN   42.0                       کتاب کودکان
# 3755  9786226091237     NaN   26.0                       کتاب کودکان
# 3756  ۹۷۸۶۲۲۹۹۱۷۳۱۲     NaN   45.0                       کتاب کودکان
# 3757  9786001194245    4.43   96.0                          نشر قطره
# 3758  9789643636302    4.43  142.0                              هرمس
# 3759  9786942995172    4.50  317.0                      نشر شورآفرین
# 3760  9786004051613    4.43  377.0                          نشر ثالث
# 3761  9786002911179    4.43  764.0                              ویدا
# 3762  9786009484478    4.83  288.0                     انتشارات مجید
# 3763  9786007212356    5.00  372.0                     انتشارات تیسا
# 3764  9786226091404     NaN   61.0                       کتاب کودکان
# 3765  9789642895038    3.86  227.0                     انتشارات جویا
# 3766  9786226091435     NaN   31.0                       کتاب کودکان
# 3767  9786226091312     NaN   52.0                       کتاب کودکان
# 3768  9786226091411     NaN   53.0                       کتاب کودکان
# 3769  9786226091329     NaN   65.0                       کتاب کودکان
# 3770  9786226091336     NaN   72.0                       کتاب کودکان
# 3771  9786005334272     NaN  208.0                           کتاب طه
# 3772  9786009852369     NaN   24.0                       کتاب کودکان
# 3773   978600985238     NaN   24.0                       کتاب کودکان
# 3774  9786226091343     NaN   47.0                       کتاب کودکان
# 3775  9789641940401    4.83  294.0  انتشارات روشنگران و مطالعات زنان
# 3776  9786226091398     NaN   60.0                       کتاب کودکان
# 3777  ۹۷۸۶۰۰۹۸۵۲۳۷۶     NaN   24.0                       کتاب کودکان
#
#       price_diff
# 0         7000.0
# 1        16000.0
# 2         8000.0
# 3            NaN
# 4        10000.0
# 5        16800.0
# 6         9000.0
# 7        25000.0
# 8        11250.0
# 9         7200.0
# 10       18750.0
# 11           NaN
# 12        7200.0
# 13           NaN
# 14        9000.0
# 15        5600.0
# 16        3110.0
# 17           NaN
# 18       27000.0
# 19        7000.0
# 20       20000.0
# 21       15000.0
# 22           NaN
# 23       11500.0
# 24       17000.0
# 25       10800.0
# 26        6500.0
# 27        5000.0
# 28           NaN
# 29        8500.0
# ...          ...
# 3748         NaN
# 3749         NaN
# 3750     11000.0
# 3751         NaN
# 3752      6000.0
# 3753      6000.0
# 3754         NaN
# 3755      6000.0
# 3756      7000.0
# 3757         NaN
# 3758      3600.0
# 3759         NaN
# 3760         NaN
# 3761     23000.0
# 3762     12500.0
# 3763         NaN
# 3764      8000.0
# 3765      3000.0
# 3766      8000.0
# 3767      8000.0
# 3768      8000.0
# 3769      8000.0
# 3770      8000.0
# 3771      6000.0
# 3772         NaN
# 3773         NaN
# 3774      8000.0
# 3775         NaN
# 3776      8000.0
# 3777      9000.0
#
# [3778 rows x 8 columns]

# %% [markdown]
# obviously paper price and price have high correlation but the intresting part is correlation between (price diff,price) and (price diff,paper price). paper price has more corr with price diff this shows that fidibo tries to balance prices in a way that higher paper price have more price diff. another thing to notice is that page has corr with price which is reasonable.

# %%
lm1 = sns.lmplot(x="paper_price", y="price_diff", data=data)
fig1 = lm1.fig 
fig1.suptitle("paper_price and price_diff")

lm2 = sns.lmplot(x="price", y="price_diff", data=data)
fig2 = lm2.fig 
fig2.suptitle('price and price_diff')
plt.show()

# %% [markdown]
# ## Model data to estimate price
# one thing that we can do is to estimate price of books by PCA and regression

# %%
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split

y = data["price"]
X = data.iloc[:,[2,4,5]]
X['paper_price'] = X['paper_price']/100
X['rating'] = X['rating']*100
X = X.fillna(X.mean())
X.head()


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

pca=PCA(n_components=2) 
X_train = pca.fit(X_train) 
X_test=pca.transform(X_test) 
pca.explained_variance_ratio_
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# array([0.70746281, 0.218839  ])

# %% [markdown]
# It can be seen that first principal component is responsible for 70% of our model so it's safe to convert it to one component

# %%
y = data["price"]
X = data.iloc[:,[2,4,5]]
X['paper_price'] = X['paper_price']/100
X['rating'] = X['rating']*100
X = X.fillna(X.mean())
X.head()


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)
pca=PCA(n_components=1) 
pca.fit(X_train) 
X_train=pca.transform(X_train) 
X_test=pca.transform(X_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %% [markdown]
# ### Regression

# %%
from sklearn.linear_model import LinearRegression  
regressor = LinearRegression()  
regressor.fit(X_train, y_train)
print(regressor.intercept_) 
print(regressor.coef_)
y_pred = regressor.predict(X_test) 
test_results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
accuracy = regressor.score(X_test,y_test)
print(accuracy*100,'%')
plt.scatter(X_train, y_train,color='b')
plt.plot(X_test, y_pred,color='k')
plt.savefig('result_reg.png')
plt.show()
# Out:
# 8888.230972865651
# [25.22520831]
# 59.16127391905792 %

# %% [markdown]
# good :)

# %% [markdown]
# ## Publishers correlation with the price and more

# %%
publishers_data =  data.groupby('publisher').agg({'price': 'mean'})
plt.hist(publishers_data['price'], 100, facecolor='k')
plt.show()
sns.swarmplot(x='publisher',y='price',data=data)
plt.show()

# %% [markdown]
# some publishers' books are more expensive than usual let's see what they are

# %%
expensive_publishers = publishers_data[publishers_data['price']>25000]
expensive_publishers
# Out:
#                                      price
# publisher
# انتشارات سنجش و دانش          33180.000000
# فیدیبو                        30931.774194
# موسسه فرهنگی هنری سانازسانيا  45000.000000
# نشر بارسا                     35000.000000
# نشر تیر                       25333.333333

# %% [markdown]
# these are expensive publishers...
# what came to my mind is to add publishers data to our regression model so let's see how many publisher we have

# %%
data.drop_duplicates(subset=['publisher'], keep=False).shape
# Out:
# (64, 8)

# %% [markdown]
# we have 64 unique publisher (actually I excepted more) so it's a good Idea to include them (as dummy var) to our reg model

# %%
dum_data = pd.get_dummies(data.iloc[:,[2,4,5,6]], columns=['publisher'])
dum_data
# PCA and regression with publishers
y = data["price"]
X = dum_data
X['paper_price'] = X['paper_price']/100
X['rating'] = X['rating']*100
X = X.fillna(X.mean())
X
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)
pca=PCA(n_components=65) 
pca.fit(X_train) 
X_train=pca.transform(X_train) 
X_test=pca.transform(X_test)


regressor1 = LinearRegression()  
regressor1.fit(X_train, y_train)
y_pred = regressor1.predict(X_test) 
w_publisher_test_results = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
accuracy = regressor1.score(X_test,y_test)
print(accuracy*100,'%')
w_publisher_test_results
# Out:
# 76.10529454880546 %
#       Actual     Predicted
# 666    10200   6571.391229
# 314     4200   5656.242491
# 1372    2900   2221.494446
# 3165   10200   8334.113171
# 1703    2000   2022.325748
# 1320    6750   6550.006458
# 3026    3900   3115.809470
# 1105    6000   8963.434212
# 1346    9400  13798.169064
# 415    13500  12223.289539
# 1773   14000  13488.794482
# 9      10800   9948.933994
# 3677   10200   9448.954197
# 1981    8550   7140.546809
# 3348    4400   5086.560648
# 1770    9800   6845.297823
# 870     4200   6765.551135
# 147    15900  23006.116956
# 3544    7000  19755.964630
# 2449   16000  15183.436396
# 3484    4800   6709.814017
# 2947    8000   8743.835492
# 2670   13900  14264.018555
# 2598    3800   6693.246056
# 3571    2000   1104.634619
# 2390   10500  10450.267114
# 126    12000  11956.216770
# 887     8550   7140.546809
# 2148   16000  13804.729660
# 917     4900   5637.790993
# ...      ...           ...
# 3138    3000  10702.884829
# 2304    5800   6645.117324
# 2035   14900  12683.398581
# 2581    9000   7653.946343
# 3421    1500   6511.327104
# 2960    6000   7822.124323
# 1814    5700   6517.939449
# 1849   12000  14416.323510
# 2102    7500   5656.565339
# 2687    3500   1557.584434
# 1192   11400  10584.134569
# 501    14500  10507.624756
# 3087    2000   2144.833456
# 1932    5000   3701.110598
# 1927    2500   3215.980903
# 1692   10000  12526.705065
# 515    20900  12068.604372
# 2273   12600  11623.528914
# 2602   33000  26236.885654
# 1380    6750   6841.945754
# 228     8000   8465.643758
# 2352   25500  13600.677260
# 3564    4000   3835.201432
# 2267   20000  18825.880552
# 3735    2000   1052.923220
# 3386    4500   6880.997124
# 1325    2200   6021.004669
# 2652   10800  11394.521862
# 431     2000   3050.127056
# 821     5400   5058.020538
#
# [756 rows x 2 columns]
